# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv("C:\\Users\\Amir\\OneDrive\\Desktop\\sales_data.CSV")

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  26/11/2013   26  November  2013            19     Youth (<25)
# 1  26/11/2015   26  November  2015            19     Youth (<25)
# 2  23/03/2014   23     March  2014            49  Adults (35-64)
# 3  23/03/2016   23     March  2016            49  Adults (35-64)
# 4  15/05/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category  ...  \
# 0               M     Canada  British Columbia      Accessories  ...
# 1               M     Canada  British Columbia      Accessories  ...
# 2               M  Australia   New South Wales      Accessories  ...
# 3               M  Australia   New South Wales      Accessories  ...
# 4               F  Australia   New South Wales      Accessories  ...
#
#   Order_Quantity Unit_Cost  Unit_Price  Profit  Cost  Revenue  Unnamed: 18  \
# 0              8        45         120     590   360      950          NaN
# ...

# %%
sales.tail()
# Out:
#               Date  Day  Month  Year  Customer_Age       Age_Group  \
# 113031  2016-04-12   12  April  2016            41  Adults (35-64)
# 113032  2014-04-02    2  April  2014            18     Youth (<25)
# 113033  2016-04-02    2  April  2016            18     Youth (<25)
# 113034  2014-03-04    4  March  2014            37  Adults (35-64)
# 113035  2016-03-04    4  March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# 113031               M  United Kingdom        England         Clothing
# 113032               M       Australia     Queensland         Clothing
# 113033               M       Australia     Queensland         Clothing
# 113034               F          France  Seine (Paris)         Clothing
# 113035               F          France  Seine (Paris)         Clothing
#
#        Sub_Category          Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %%
sales.drop_duplicates(subset=None, keep=False)
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
sns.countplot(x='Customer_Gender', data=sales)
plt.title('Distribution of Customer Genders')
plt.xticks(rotation=45)

total = float(len(sales))
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().text(p.get_x() + p.get_width() / 2, height + 3, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=12)

# %%
plt.hist('Customer_Age', data=sales[sales['Customer_Gender'] == 'M'], label= 'Male')
plt.hist('Customer_Age', data=sales[sales['Customer_Gender'] == 'F'], label= 'Female')
plt.title('Distribution of Age by Gender')
plt.xlabel('Age')
plt.legend()

# %%
sns.countplot(x='Age_Group', data=sales)
plt.title('Distribution of Age Groups')
plt.xticks(rotation=45)

total = float(len(sales))
for p in plt.gca().patches:
    height = p.get_height()
    plt.gca().text(p.get_x() + p.get_width() / 2, height + 3, '{:.1f}%'.format((height / total) * 100), ha='center', fontsize=12)

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %%
labels= ['Accessories', 'Bikes', 'Clothing']

colors=['blue', 'yellow', 'red']

sizes= [1500, 600, 500]

plt.pie(sizes,labels=labels, colors=colors, startangle=90, autopct='%1.2f%%')

plt.title('Product_Category')

plt.axis('equal')

plt.show()

# %%
sales.hist('Customer_Age', bins=20)
plt.title('Ages Distribution')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
male_customers = sales[sales['Customer_Gender'] == 'M']
female_customers = sales[sales['Customer_Gender'] == 'F']

# Print the average spending score for men and women
print(male_customers['Order_Quantity'].mean())
print(female_customers['Order_Quantity'].mean())
# Out:
# 11.997238990259294
# 11.79981361011622

# %%
sns.countplot(x='Year',hue='Product_Category',data=sales)
plt.title("Product categories by year")
# Out:
# Text(0.5, 1.0, 'Product categories by year')

# %%
sns.scatterplot(x='Cost', y='Profit', data=sales, hue='Customer_Gender')
plt.xlim(0,6000)
plt.ylim(0,6000)

plt.xlabel('Cost')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.scatterplot(x='Cost', y='Revenue', data=sales, hue='Customer_Gender')
plt.xlim(0,6000)
plt.ylim(0,12000)

plt.xlabel('Cost')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %%
sns.scatterplot(x='Profit', y='Revenue', data=sales, hue='Customer_Gender')
plt.xlim(0,6000)
plt.ylim(0,20000)

plt.xlabel('Profit')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %%
sns.countplot(x='Country',hue='Product_Category',data=sales, width=0.6)
plt.title("Product categories by Country")
# Out:
# Text(0.5, 1.0, 'Product categories by Country')

# %%
us = sales.loc[(sales['Country'] == 'United States', 'Product_Category')].value_counts()

us
# Out:
# Product_Category
# Accessories    25042
# Bikes           8028
# Clothing        6136
# Name: count, dtype: int64
